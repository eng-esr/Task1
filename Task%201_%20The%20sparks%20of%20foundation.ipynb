# %% [markdown]
# # name:esraa yaseen
# task1:data science and business analytics the sparks foundation intern

# %% [markdown]
# # Exploratory Data Analysis_Retail
# on dataset samplesuperstore

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set()

# %%
store =pd.read_csv('SampleSuperstore.csv')
store
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
store.head(10)
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 5  Standard Class   Consumer  United States      Los Angeles  California
# 6  Standard Class   Consumer  United States      Los Angeles  California
# 7  Standard Class   Consumer  United States      Los Angeles  California
# 8  Standard Class   Consumer  United States      Los Angeles  California
# 9  Standard Class   Consumer  United States      Los Angeles  California
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# ...

# %%
store.tail(10)
# Out:
#            Ship Mode    Segment        Country         City       State  \
# 9984  Standard Class   Consumer  United States   Long Beach    New York
# 9985  Standard Class   Consumer  United States   Long Beach    New York
# 9986  Standard Class   Consumer  United States  Los Angeles  California
# 9987  Standard Class  Corporate  United States       Athens     Georgia
# 9988  Standard Class  Corporate  United States       Athens     Georgia
# 9989    Second Class   Consumer  United States        Miami     Florida
# 9990  Standard Class   Consumer  United States   Costa Mesa  California
# 9991  Standard Class   Consumer  United States   Costa Mesa  California
# 9992  Standard Class   Consumer  United States   Costa Mesa  California
# 9993    Second Class   Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9984        11561   East  Office Supplies       Labels   31.500        10
# ...

# %%
store.describe().round(2)
# Out:
#        Postal Code     Sales  Quantity  Discount   Profit
# count      9994.00   9994.00   9994.00   9994.00  9994.00
# mean      55190.38    229.86      3.79      0.16    28.66
# std       32063.69    623.25      2.23      0.21   234.26
# min        1040.00      0.44      1.00      0.00 -6599.98
# 25%       23223.00     17.28      2.00      0.00     1.73
# 50%       56430.50     54.49      3.00      0.20     8.67
# 75%       90008.00    209.94      5.00      0.20    29.36
# max       99301.00  22638.48     14.00      0.80  8399.98

# %%
store.shape
# Out:
# (9994, 13)

# %%
store.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
store.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# # sample super store EDA

# %%
store.isna().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
plt.figure(figsize=(20 , 10))
sns.heatmap(store.isna()) #cbar=False
plt.show()

# %%
store[store.duplicated(subset=None)]
# Out:
#            Ship Mode      Segment        Country           City         State  \
# 950   Standard Class  Home Office  United States   Philadelphia  Pennsylvania
# 3406  Standard Class  Home Office  United States       Columbus          Ohio
# 3670  Standard Class     Consumer  United States          Salem        Oregon
# 4117  Standard Class     Consumer  United States    Los Angeles    California
# 4553  Standard Class     Consumer  United States  San Francisco    California
# 5905        Same Day  Home Office  United States  San Francisco    California
# 6146  Standard Class    Corporate  United States  San Francisco    California
# 6334  Standard Class     Consumer  United States  New York City      New York
# 6357  Standard Class    Corporate  United States        Seattle    Washington
# 7608  Standard Class     Consumer  United States  San Francisco    California
# 7735  Standard Class    Corporate  United States        Seattle    Washington
# ...

# %%
store.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
store['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
store.groupby('Ship Mode')['Category'].count().reset_index()
# Out:
#         Ship Mode  Category
# 0     First Class      1538
# 1        Same Day       543
# 2    Second Class      1945
# 3  Standard Class      5968

# %%
store['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
store['Category'].value_counts()
# Out:
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: Category, dtype: int64

# %%
store['Sub-Category'].value_counts()
# Out:
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: Sub-Category, dtype: int64

# %%
store['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
store['City'].unique()
# Out:
# array(['Henderson', 'Los Angeles', 'Fort Lauderdale', 'Concord',
#        'Seattle', 'Fort Worth', 'Madison', 'West Jordan', 'San Francisco',
#        'Fremont', 'Philadelphia', 'Orem', 'Houston', 'Richardson',
#        'Naperville', 'Melbourne', 'Eagan', 'Westland', 'Dover',
#        'New Albany', 'New York City', 'Troy', 'Chicago', 'Gilbert',
#        'Springfield', 'Jackson', 'Memphis', 'Decatur', 'Durham',
#        'Columbia', 'Rochester', 'Minneapolis', 'Portland', 'Saint Paul',
#        'Aurora', 'Charlotte', 'Orland Park', 'Urbandale', 'Columbus',
#        'Bristol', 'Wilmington', 'Bloomington', 'Phoenix', 'Roseville',
#        'Independence', 'Pasadena', 'Newark', 'Franklin', 'Scottsdale',
#        'San Jose', 'Edmond', 'Carlsbad', 'San Antonio', 'Monroe',
#        'Fairfield', 'Grand Prairie', 'Redlands', 'Hamilton', 'Westfield',
#        'Akron', 'Denver', 'Dallas', 'Whittier', 'Saginaw', 'Medina',
#        'Dublin', 'Detroit', 'Tampa', 'Santa Clara', 'Lakeville',
# ...

# %%
store['City'].nunique()
# Out:
# 531

# %%
cities_count = store['City'].value_counts().nlargest(10).reset_index()
cities_count
# Out:
#            index  City
# 0  New York City   915
# 1    Los Angeles   747
# 2   Philadelphia   537
# 3  San Francisco   510
# 4        Seattle   428
# 5        Houston   377
# 6        Chicago   314
# 7       Columbus   222
# 8      San Diego   170
# 9    Springfield   163

# %%
cities_count = store['City'].value_counts().nsmallest(10).reset_index()
cities_count
# Out:
#            index  City
# 0       Bartlett     1
# 1    Port Orange     1
# 2  Missouri City     1
# 3      Iowa City     1
# 4   Ormond Beach     1
# 5     Springdale     1
# 6      Littleton     1
# 7      Vacaville     1
# 8        Portage     1
# 9        Redding     1

# %%
store['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
store['Region'].nunique()
# Out:
# 4

# %%
regiones_count = store['Region'].value_counts().nlargest().reset_index()
regiones_count
# Out:
#      index  Region
# 0     West    3203
# 1     East    2848
# 2  Central    2323
# 3    South    1620

# %%
store['Profit'].sum()
# Out:
# 286397.0217

# %%
q1 = store.describe()['Profit']['25%']
q3 = store.describe()['Profit']['75%']
iqr = q3 - q1
max_profit = q3 + 1.5 * iqr
print(max_profit)
# Out:
# 70.816875

# %%
outliers = store[store['Profit'] >= max_profit]
outliers_count = outliers['Profit'].count()
store_count = store['Profit'].count()
print('Percentage removed: ' + str(round(outliers_count/store_count * 100, 2)) + '%')
# Out:
# Percentage removed: 12.78%

# %%
sns.boxplot(x='Profit', data = store)
plt.show()

# %%
store['Sales'].sort_values()
# Out:
# 4101        0.444
# 9292        0.556
# 8658        0.836
# 4711        0.852
# 2106        0.876
#           ...
# 4190    10499.970
# 2623    11199.968
# 8153    13999.960
# 6826    17499.950
# 2697    22638.480
# Name: Sales, Length: 9994, dtype: float64

# %%
store.groupby('City')['Sales'].sum().nlargest(20).reset_index()
# Out:
#              City        Sales
# 0   New York City  256368.1610
# 1     Los Angeles  175851.3410
# 2         Seattle  119540.7420
# 3   San Francisco  112669.0920
# 4    Philadelphia  109077.0130
# 5         Houston   64504.7604
# 6         Chicago   48539.5410
# 7       San Diego   47521.0290
# 8    Jacksonville   44713.1830
# 9     Springfield   43054.3420
# 10        Detroit   42446.9440
# 11       Columbus   38706.2430
# 12         Newark   28576.1190
# 13       Columbia   25283.3240
# 14      Lafayette   25036.2000
# 15        Jackson   24963.8580
# 16    San Antonio   21843.5280
# 17     Burlington   21668.0820
# 18      Arlington   20214.5320
# 19         Dallas   20131.9322

# %%
store.groupby('City')['Quantity'].sum().nlargest(20).reset_index()
# Out:
#              City  Quantity
# 0   New York City      3417
# 1     Los Angeles      2879
# 2    Philadelphia      1981
# 3   San Francisco      1935
# 4         Seattle      1590
# 5         Houston      1466
# 6         Chicago      1132
# 7        Columbus       836
# 8       San Diego       670
# 9     Springfield       649
# 10         Dallas       555
# 11        Detroit       441
# 12   Jacksonville       429
# 13         Newark       362
# 14       Richmond       336
# 15        Jackson       318
# 16       Columbia       316
# 17      Arlington       259
# 18         Aurora       258
# 19     Long Beach       256

# %%
store.groupby('City')['Discount'].sum().nlargest(20).reset_index()
# Out:
#              City  Discount
# 0    Philadelphia    175.50
# 1         Houston    143.14
# 2         Chicago    120.50
# 3          Dallas     56.30
# 4     Los Angeles     55.50
# 5   New York City     51.40
# 6        Columbus     38.50
# 7    Jacksonville     35.85
# 8   San Francisco     34.00
# 9         Seattle     27.80
# 10         Aurora     24.00
# 11    Springfield     23.20
# 12    San Antonio     22.60
# 13        Phoenix     22.30
# 14          Miami     18.65
# 15      Charlotte     15.30
# 16      Lancaster     14.50
# 17      San Diego     13.60
# 18         Austin     13.40
# 19      Cleveland     12.80

# %%
store.groupby('City')['Profit'].sum().nlargest(20).reset_index()
# Out:
#              City      Profit
# 0   New York City  62036.9837
# 1     Los Angeles  30440.7579
# 2         Seattle  29156.0967
# 3   San Francisco  17507.3854
# 4         Detroit  13181.7908
# 5       Lafayette  10018.3876
# 6         Jackson   7581.6828
# 7         Atlanta   6993.6629
# 8     Minneapolis   6824.5846
# 9       San Diego   6377.1960
# 10    Springfield   6200.6974
# 11       Columbus   5897.1013
# 12         Newark   5793.7588
# 13       Columbia   5606.1167
# 14       Richmond   5567.2486
# 15     Providence   5505.6569
# 16      Henderson   4911.8609
# 17      Arlington   4169.6969
# 18       Lakewood   3234.0278
# 19      Milwaukee   2793.0851

# %% [markdown]
# # viz

# %%
sns.heatmap(store.corr())
# Out:
# <AxesSubplot:>

# %%
store.plot(subplots=True , figsize=(10 , 10))
plt.show()

# %%
sns.set_context('talk' ,font_scale=1)
plt.figure(figsize=(20,10))
sns.countplot(store['Ship Mode'],order = store['Ship Mode'].value_counts().index)
plt.title('top Ship Mode \n')
plt.ylabel('total Ship Mode')
plt.xlabel('city Ship Mode')
plt.show()
# Out:
# C:\Users\herzo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set_context('talk' ,font_scale=1)
plt.figure(figsize=(20,10))
sns.countplot(store['Segment'],order = store['Segment'].value_counts().index)
plt.title(' Segment \n')
plt.ylabel('total Segment')
plt.xlabel('sort of Segment')
plt.show()
# Out:
# C:\Users\herzo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set_context('talk' ,font_scale=1.5)
plt.figure(figsize=(20,10))
sns.countplot(store['State'],order = store['State'].value_counts().nlargest(10).index)
plt.title('top 10 State \n')
plt.ylabel('total State')
plt.xlabel('States names')
plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\herzo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set_context('talk' ,font_scale=1.5)
plt.figure(figsize=(20,10))
sns.countplot(store['City'],order = store['City'].value_counts().nlargest(10).index)
plt.title('top 10 city \n')
plt.ylabel('total city')
plt.xlabel('city names')
plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\herzo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set_context('talk' ,font_scale=2)
plt.figure(figsize=(20,10))
sns.countplot(store['Region'],order = store['Region'].value_counts().nlargest(10).index)
plt.title('top Region \n')
plt.ylabel('total Region')
plt.xlabel('Region names')
plt.show()
# Out:
# C:\Users\herzo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.set_context('talk' ,font_scale=1.5)
plt.figure(figsize=(20,10))
sns.countplot(store['Sub-Category'],order = store['Sub-Category'].value_counts().index)              
plt.title('top Sub-Category \n')
plt.ylabel('total Sub-Category ')
plt.xlabel('Sub-Category names')
plt.xticks(rotation = 90)
plt.show()
# Out:
# C:\Users\herzo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(20,10))
data_manu=store.groupby('City')['Sales'].sum().nlargest(10).reset_index()
data_manu.plot.scatter(x = 'City' , y = 'Sales' )
plt.xticks(rotation=90)
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
plt.figure(figsize=(20,10))
data_manu=store.groupby('City')['Quantity'].sum().nlargest(10).reset_index()
data_manu.plot.scatter(x = 'City' , y = 'Quantity'  )
plt.xticks(rotation=90)
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
plt.figure(figsize=(20,10))
data_manu=store.groupby('City')['Discount'].sum().nlargest(10).reset_index()
data_manu.plot.scatter(x = 'City' , y = 'Discount'  )
plt.xticks(rotation=90)
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
plt.figure(figsize=(20,10))
data_manu=store.groupby('City')['Profit'].sum().nlargest(10).reset_index()
data_manu.plot.scatter(x = 'City' , y = 'Profit'  )
plt.xticks(rotation=90)
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
